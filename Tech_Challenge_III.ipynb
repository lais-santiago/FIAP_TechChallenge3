# %% [markdown]
# <a href="https://colab.research.google.com/github/lais-santiago/FIAP_TechChallenge3/blob/main/Tech_Challenge_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1) Preparação dos dados através do Google Big Query

# %% [markdown]
# ### Bases de dados obtidas do site do IBGE foram de microdados
# * PNAD_COVID_092020
# * PNAD_COVID_102020
# * PNAD_COVID_112020
#
# ### Informações de identificação e controle selecionadas
# * Unidade da Federação
# * Semana no mês
# * Mês da pesquisa
# * Situação do domicílio
# * Tipo de área
#
# ### Informações de características gerais dos moradores selecionadas
# * Idade do morador
# * Sexo
#
# ### Informações relacionadas a COVID selecionadas
# * Na semana passada teve febre?
# * Na semana passada teve tosse?
# * Na semana passada teve dor de garganta?
# * Na semana passada teve dificuldade para respirar?
# * Na semana passada teve dor de cabeça?
# * Na semana passada teve dor no peito?
# * Na semana passada teve náusea?
# * Na semana passada teve nariz entupido ou escorrendo?
# * Na semana passada teve fadiga?
# * Na semana passada teve dor nos olhos?
# * Na semana passada teve perda de cheiro ou sabor?
# * Na semana passada teve dor muscular?
# * Na semana passada teve diarreia?
# * Por causa disso, foi a algum estabelecimento de saúde?
# * Providência tomada  para recuperar dos sintomas foi comprar e/ou tomar  remédio por conta própria
# * Providência tomada para recuperar dos sintomas foi comprar e/ou tomar remédio por orientação médica
# * Local que buscou atendimento foi posto de saúde/Unidade básica de saúde /Equipe de Saúde da Família (médico, enfermeiro, técnico de enfermagem ou agente comunitário de saúde)
# * Local que buscou atendimento foi pronto socorro do SUS/UPA
# * Local que buscou atendimento foi hospital do SUS
# * Local que buscou atendimento foi ambulatório ou consultório privado ou ligado às forças armadas
# * Local que buscou atendimento foi pronto socorro privado ou ligado às forças armadas
# * Local que buscou atendimento foi hospital privado ou ligado às forças armadas
# * O(A) Sr(a) fez algum teste para saber se estava infectado(a) pelo coronavírus?
# * Qual o resultado?
# * Algum médico já lhe deu o diagnóstico de diabetes?
# * Algum médico já lhe deu o diagnóstico de hipertensão?
# * Algum médico já lhe deu o diagnóstico de asma/bronquite/enfisema/doenças respiratória crônica ou doença de pulmão?
# * Algum médico já lhe deu o diagnóstico de doenças do coração (infarto, angina, insuficiência cardíaca, arritmia)?
# * Algum médico já lhe deu o diagnóstico de câncer?
# * Qual foi o resultado do teste?  Na semana passada, devido à pandemia do Coronavírus, em que medida o(a) Sr(a) restringiu o contato com as pessoas?
#
# ### Características de trabalho das pessoas acima de 14 anos selecionadas
# * No trabalho (único ou principal) que tinha nessa semana, era:
# * Tem carteira de trabalho assinada ou é funcionário público estatutário?
# * Número da faixa do rendimento/retirada em dinheiro
# * Na semana passada, o(a) Sr(a) estava em trabalho remoto (home office ou teletrabalho)?
#
#
# ### Características de rendimento de outras fontes dos moradores de 14 anos ou mais selecionadas
# * Auxílios emergenciais relacionados ao coronavirus
# * Seguro desemprego
#
#
# ### Características de Empréstimos selecionadas
# * Durante o período da pandemia alguém deste domicílio solicitou algum empréstimo?
#
# ### Características da habitação selecionadas
# * No seu domicílio há os seguintes itens básicos de limpeza e proteção: sabão ou detergente
# * No seu domicílio há os seguintes itens básicos de limpeza e proteção: álcool 70% ou superior (gel ou líquido)
# * No seu domicílio há os seguintes itens básicos de limpeza e proteção: máscaras
# * No seu domicílio há os seguintes itens básicos de limpeza e proteção: luvas descartáveis
# * No seu domicílio há os seguintes itens básicos de limpeza e proteção: água sanitária ou desinfetante
#
#
# ### Foram realizados os seguintes agrupamentos de informações para reduzir a 20 questionamentos
# * Teve ao menos 1 sintoma relacionado a covid?
# 	* Na semana passada teve febre?
# 	* Na semana passada teve tosse?
# 	* Na semana passada teve dor de garganta?
# 	* Na semana passada teve dificuldade para respirar?
# 	* Na semana passada teve dor de cabeça?
# 	* Na semana passada teve dor no peito?
# 	* Na semana passada teve náusea?
# 	* Na semana passada teve nariz entupido ou escorrendo?
# 	* Na semana passada teve fadiga?
# 	* Na semana passada teve dor nos olhos?
# 	* Na semana passada teve perda de cheiro ou sabor?
# 	* Na semana passada teve dor muscular?
# 	* Na semana passada teve diarreia?
# * Buscou atendimento público (SUS)?
# 	* Local que buscou atendimento foi posto de saúde/Unidade básica de saúde /Equipe de Saúde da Família (médico, enfermeiro, técnico de enfermagem ou agente comunitário de saúde)
# 	* Local que buscou atendimento foi pronto socorro do SUS/UPA
# 	* Local que buscou atendimento foi hospital do SUS
# * Buscou atendimento privado?
# 	* Local que buscou atendimento foi ambulatório ou consultório privado ou ligado às forças armadas
# 	* Local que buscou atendimento foi pronto socorro privado ou ligado às forças armadas
# 	* Local que buscou atendimento foi hospital privado ou ligado às forças armadas
# * Resultado do teste
# * Possuía alguma comorbidade?
# 	* Algum médico já lhe deu o diagnóstico de diabetes?
# 	* Algum médico já lhe deu o diagnóstico de hipertensão?
# 	* Algum médico já lhe deu o diagnóstico de asma/bronquite/enfisema/doenças respiratória crônica ou doença de pulmão?
# 	* Algum médico já lhe deu o diagnóstico de doenças do coração (infarto, angina, insuficiência cardíaca, arritmia)?
# 	* Algum médico já lhe deu o diagnóstico de câncer?
# * Possuía acesso aos itens básicos de limpeza e proteção?
# 	* No seu domicílio há os seguintes itens básicos de limpeza e proteção: sabão ou detergente
# 	* No seu domicílio há os seguintes itens básicos de limpeza e proteção: álcool 70% ou superior (gel ou líquido)
# 	* No seu domicílio há os seguintes itens básicos de limpeza e proteção: máscaras
# 	* No seu domicílio há os seguintes itens básicos de limpeza e proteção: luvas descartáveis
# 	* No seu domicílio há os seguintes itens básicos de limpeza e proteção: água sanitária ou desinfetante
#
#
# ### Query executada nas tabelas
# ```
# SELECT
#   CASE
#     WHEN UF = 11 THEN 'Rondônia'
#     WHEN UF = 12 THEN 'Acre'
#     WHEN UF = 13 THEN 'Amazonas'
#     WHEN UF = 14 THEN 'Roraima'
#     WHEN UF = 15 THEN 'Pará'
#     WHEN UF = 16 THEN 'Amapá'
#     WHEN UF = 17 THEN 'Tocantins'
#     WHEN UF = 21 THEN 'Maranhão'
#     WHEN UF = 22 THEN 'Piauí'
#     WHEN UF = 23 THEN 'Ceará'
#     WHEN UF = 24 THEN 'Rio Grande do Norte'
#     WHEN UF = 25 THEN 'Paraíba'
#     WHEN UF = 26 THEN 'Pernambuco'
#     WHEN UF = 27 THEN 'Alagoas'
#     WHEN UF = 28 THEN 'Sergipe'
#     WHEN UF = 29 THEN 'Bahia'
#     WHEN UF = 31 THEN 'Minas Gerais'
#     WHEN UF = 32 THEN 'Espírito Santo'
#     WHEN UF = 33 THEN 'Rio de Janeiro'
#     WHEN UF = 35 THEN 'São Paulo'
#     WHEN UF = 41 THEN 'Paraná'
#     WHEN UF = 42 THEN 'Santa Catarina'
#     WHEN UF = 43 THEN 'Rio Grande do Sul'
#     WHEN UF = 50 THEN 'Mato Grosso do Sul'
#     WHEN UF = 51 THEN 'Mato Grosso'
#     WHEN UF = 52 THEN 'Goiás'
#     WHEN UF = 53 THEN 'Distrito Federal'
#   END AS unidade_federativa,
#   V1012 AS semana_do_mes,
#   CASE
#     WHEN V1013 = 1 THEN 'Janeiro'
#     WHEN V1013 = 2 THEN 'Fevereiro'
#     WHEN V1013 = 3 THEN 'Março'
#     WHEN V1013 = 4 THEN 'Abril'
#     WHEN V1013 = 5 THEN 'Maio'
#     WHEN V1013 = 6 THEN 'Junho'
#     WHEN V1013 = 7 THEN 'Julho'
#     WHEN V1013 = 8 THEN 'Agosto'
#     WHEN V1013 = 9 THEN 'Setembro'
#     WHEN V1013 = 10 THEN 'Outubro'
#     WHEN V1013 = 11 THEN 'Novembro'
#     WHEN V1013 = 12 THEN 'Dezembro'
#   END AS mes,
#   CASE
#     WHEN V1022 = 1 THEN 'urbana'
#     WHEN V1022 = 2 THEN 'rural'
#   END AS situacao_domicilio,
#   CASE
#     WHEN V1023 = 1 THEN 'Capital'
#     WHEN V1023 = 2 THEN 'Resto da Região Metropolitana'
#     WHEN V1023 = 3 THEN 'Resto da RIDE'
#     WHEN V1023 = 4 THEN 'Resto da UF'
#   END AS tipo_area,
#   A002 AS idade_morador,
#   CASE
#     WHEN A003 = 1 THEN 'homem'
#     WHEN A003 = 2 THEN 'mulher'
#   END AS sexo,
#   CASE
#     WHEN 1 IN (B0011, B0012, B0013, B0014, B0015, B0016, B0017, B0018, B0019, B00110, B00111, B00112, B00113) THEN 'S'
#     ELSE 'N'
#   END AS teve_sintomas,
#   CASE
#     WHEN B002 = 1 THEN 'S'
#     ELSE 'N'
#   END AS visitou_estabelecimento_saude,
#   CASE
#     WHEN B0033 = 1 THEN 'S'
#     ELSE 'N'
#   END AS tomou_remedio_conta_propria,
#   CASE
#     WHEN B0034 = 1 THEN 'S'
#     ELSE 'N'
#   END AS tomou_remedio_com_orientacao_medica,
#   CASE
#     WHEN 1 IN (B0041, B0042, B0043, B0044, B0045, B0046) THEN 'S'
#     ELSE 'N'
#   END AS buscou_atendimento_medico,
#   CASE
#     WHEN 1 IN (B0041, B0042, B0043) THEN 'S'
#     ELSE 'N'
#   END AS atendimento_sus,
#   CASE
#     WHEN 1 IN (B0044, B0045, B0046) THEN 'S'
#     ELSE 'N'
#   END AS atendimento_privado,
#   CASE
#     WHEN B008 = 1 THEN 'S'
#     ELSE 'N'
#   END AS fez_teste_covid,
#   CASE
#     WHEN 1 IN (B009B, B009D, B009F) THEN 'positivo'
#     ELSE 'N'
#   END AS resultado_teste,
#   CASE
#     WHEN 1 IN (B0101, B0102, B0103, B0104, B0106) THEN 'S'
#     ELSE 'N'
#   END AS possui_comorbidade,
#   CASE
#     WHEN B011 = 1 THEN 'sem restrição'
#     WHEN B011 = 2 THEN 'reduziu contato'
#     WHEN B011 = 3 THEN 'ficou em casa mas saiu necessidade basica'
#     WHEN B011 = 4 THEN 'ficou rigorosamente em casa'
#     ELSE ''
#   END AS restricao_contato,
#   CASE
#     WHEN C007 = 1 THEN 'trabalhador domestico'
#     WHEN C007 = 2 THEN 'militar'
#     WHEN C007 = 3 THEN 'policial militar ou bombeiro'
#     WHEN C007 = 4 THEN 'empregado setor privado'
#     WHEN C007 = 5 THEN 'empregado setor publico'
#     WHEN C007 = 6 THEN 'empregador'
#     WHEN C007 = 7 THEN 'conta propria'
#     WHEN C007 = 8 THEN 'trabalhador familiar nao remunerado'
#     WHEN C007 = 9 THEN 'fora do mercado de trabalho'
#     ELSE ''
#   END AS ocupacao,
#   CASE
#     WHEN C01011 = 00 THEN '0 - 100'
#     WHEN C01011 = 01 THEN '101 - 300'
#     WHEN C01011 = 02 THEN '301 - 600'
#     WHEN C01011 = 03 THEN '601 - 800'
#     WHEN C01011 = 04 THEN '801 - 1.600'
#     WHEN C01011 = 05 THEN '1.601 - 3.000'
#     WHEN C01011 = 06 THEN '3.001 - 10.000'
#     WHEN C01011 = 07 THEN '10.001 - 50.000'
#     WHEN C01011 = 08 THEN '50.001 - 100.000'
#     WHEN C01011 = 09 THEN 'Mais de 100.000'
#     ELSE ''
#   END AS faixa_rendimento,
#   CASE
#     WHEN C013 = 1 THEN 'S'
#     WHEN C013 = 2 THEN 'N'
#     ELSE ''
#   END AS home_office,
#   CASE
#     WHEN D0051 = 1 THEN 'S'
#     ELSE 'N'
#   END AS recebeu_auxilio_emergencial,
#   CASE
#     WHEN D0061 = 1 THEN 'S'
#     ELSE 'N'
#   END AS recebeu_seguro_desemprego,
#   CASE
#     WHEN E001 = 1 THEN 'solicitou e recebeu'
#     WHEN E001 = 2 THEN 'solicitou mas nao recebeu'
#     WHEN E001 = 3 THEN 'nao solicitou'
#   END AS solicitou_emprestimo,
#   CASE
#     WHEN 1 IN (F002A1, F002A2, F002A3, F002A4, F002A5) THEN 'S'
#   ELSE 'N'
#   END AS possui_acesso_itens_basicos_limpeza_protecao
# FROM `tech-chalenge-fiap.CJ_COVID_2020.pnad_covid_092020`;
# ```
#
# > **Observação:** Acima a query está selecionando os dados de Setembro de 2020, mas essa query foi executada também para os meses de Outubro e Novembro de 2020 com os mesmos critérios.
#
#
# ### Junção dos resultados
# ```
# SELECT * FROM `tech-chalenge-fiap.CJ_COVID_SEL.pnad_covid_092020`
# UNION ALL
# SELECT * FROM `tech-chalenge-fiap.CJ_COVID_SEL.pnad_covid_102020`
# UNION ALL
# SELECT * FROM `tech-chalenge-fiap.CJ_COVID_SEL.pnad_covid_112020`;
# ```

# %% [markdown]
# ## 2) Dados antes da execução das queries
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3) Dados após execução das queries
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4) Inicialização do Spark

# %%
'''
# !sudo apt update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#Check this site for the latest download link https://www.apache.org/dyn/closer.lua/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !wget -q https://dlcdn.apache.org/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !tar xf spark-3.2.1-bin-hadoop3.2.tgz
# !pip install -q findspark
# !pip install pyspark
# !pip install py4j

import os
import sys
# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop3.2"

import findspark
findspark.init()
findspark.find()

import pyspark

from pyspark.sql import DataFrame, SparkSession
from typing import List
import pyspark.sql.types as T
import pyspark.sql.functions as F


spark = SparkSession.builder.appName("TechChallenge_3_usando_spark").getOrCreate()

spark
'''
# Out:
# '\n!sudo apt update\n!apt-get install openjdk-8-jdk-headless -qq > /dev/null\n#Check this site for the latest download link https://www.apache.org/dyn/closer.lua/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz\n!wget -q https://dlcdn.apache.org/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz\n!tar xf spark-3.2.1-bin-hadoop3.2.tgz\n!pip install -q findspark\n!pip install pyspark\n!pip install py4j\n\nimport os\nimport sys\n# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"\n# os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop3.2"\n\nimport findspark\nfindspark.init()\nfindspark.find()\n\nimport pyspark\n\nfrom pyspark.sql import DataFrame, SparkSession\nfrom typing import List\nimport pyspark.sql.types as T\nimport pyspark.sql.functions as F\n\n\nspark = SparkSession.builder.appName("TechChallenge_3_usando_spark").getOrCreate()\n\nspark\n'

# %% [markdown]
# ## 5) Importação de bibliotecas para gerar gráficos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %% [markdown]
# ## 5) Importação do arquivo tratado pelo Google Big Query

# %%
df = spark.read.csv("/content/pnad_covid_09_10_11_2020.csv", header=True, inferSchema=True)

# %% [markdown]
# ## 6) Visualização dos dados

# %%
df.show()
# Out:
# +------------------+-------------+--------+------------------+---------+-------------+------+-------------+-----------------------------+---------------------------+-----------------------------------+-------------------------+---------------+-------------------+---------------+---------------+------------------+--------------------+--------+----------------+-----------+---------------------------+-------------------------+--------------------+--------------------------------------------+
# |unidade_federativa|semana_do_mes|     mes|situacao_domicilio|tipo_area|idade_morador|  sexo|teve_sintomas|visitou_estabelecimento_saude|tomou_remedio_conta_propria|tomou_remedio_com_orientacao_medica|buscou_atendimento_medico|atendimento_sus|atendimento_privado|fez_teste_covid|resultado_teste|possui_comorbidade|   restricao_contato|ocupacao|faixa_rendimento|home_office|recebeu_auxilio_emergencial|recebeu_seguro_desemprego|solicitou_emprestimo|possui_acesso_itens_basicos_limpeza_protecao|
# ...

# %% [markdown]
# ## 7) Visualização do schema

# %%
df.printSchema()
# Out:
# root
#  |-- unidade_federativa: string (nullable = true)
#  |-- semana_do_mes: integer (nullable = true)
#  |-- mes: string (nullable = true)
#  |-- situacao_domicilio: string (nullable = true)
#  |-- tipo_area: string (nullable = true)
#  |-- idade_morador: integer (nullable = true)
#  |-- sexo: string (nullable = true)
#  |-- teve_sintomas: string (nullable = true)
#  |-- visitou_estabelecimento_saude: string (nullable = true)
#  |-- tomou_remedio_conta_propria: string (nullable = true)
#  |-- tomou_remedio_com_orientacao_medica: string (nullable = true)
#  |-- buscou_atendimento_medico: string (nullable = true)
#  |-- atendimento_sus: string (nullable = true)
#  |-- atendimento_privado: string (nullable = true)
#  |-- fez_teste_covid: string (nullable = true)
#  |-- resultado_teste: string (nullable = true)
#  |-- possui_comorbidade: string (nullable = true)
#  |-- restricao_contato: string (nullable = true)
#  |-- ocupacao: string (nullable = true)
# ...

# %% [markdown]
# ## 8) Total de registros lidos

# %%
count = df.count()
print("Número total de registros: ", count)
# Out:
# Número total de registros:  1149197

# %% [markdown]
# ## 9) Criação de uma tabela temporária a partir do dataframe

# %%
df.createOrReplaceTempView("tabela_temporaria")

# %% [markdown]
# ## 10) Consulta da quantidade de casos confirmados de COVID de acordo com a unidade federativa. Meses selecionados foram de Setembro a Novembro de 2020.

# %%
#Seleção Geral
resultado_geral = spark.sql("SELECT unidade_federativa, count(resultado_teste) as qtd_positivos FROM tabela_temporaria WHERE resultado_teste = 'positivo' GROUP BY unidade_federativa, resultado_teste ORDER BY unidade_federativa")

resultado_geral_pd = resultado_geral.toPandas()

resultado_geral_pd = resultado_geral_pd.sort_values(by="qtd_positivos", ascending=False)

plt.figure(figsize=(10, 6))
axis=sns.barplot(x='qtd_positivos', y='unidade_federativa', data=resultado_geral_pd, palette='flare', hue='qtd_positivos')
axis.set_xlabel('Quantidade de pessoas que testaram positivo para COVID')
axis.set_ylabel('Unidade Federativa')
plt.title('Quantidade de pessoas que testaram positivo para COVID por Unidade Federativa - Setembro a Novembro 2020')

axis.xaxis.set_minor_locator(ticker.MultipleLocator(50))
axis.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.xlim(400,2300)
plt.grid(linestyle='--')

plt.show()

# %%
# Criação de lista com unidades federativas top 5 em casos com resultado positivo em teste Covid
uf_top_5 = resultado_geral_pd.head(5)['unidade_federativa'].tolist()

list_top_5 = ','.join([f"'{val}'" for val in uf_top_5])  # Transforma a lista em string com valores formatados

c
# Out:
# "'São Paulo','Rio de Janeiro','Maranhão','Goiás','Santa Catarina'"

# %% [markdown]
# ##11) Evolução da quantidade de casos positivos das top 5 Unidades Federativas  de Setembro a Novembro de 2020

# %%
#Seleção 3 meses
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, mes \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN ({list_top_5}) \
          GROUP BY  mes, unidade_federativa, resultado_teste \
          ORDER BY mes DESC, unidade_federativa"
resultado_evol = spark.sql(query)

resultado_evol_pd = resultado_evol.toPandas()

plt.figure(figsize=(10, 6))
axis=sns.lineplot(x='mes', y='qtd_positivos', hue='unidade_federativa', data=resultado_evol_pd, palette='muted')
axis.set_xlabel('Meses de 2020')
axis.set_ylabel('Quantidade de casos positivos')
axis.yaxis.set_minor_locator(ticker.MultipleLocator(100))
axis.yaxis.set_major_locator(ticker.MultipleLocator(50))
plt.ylim(400,900)
plt.title('Evolução quantidade de pessoas que testaram positivo para COVID por Unidade Federativa - Top 5')
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# ## 12) Quantidade de casos separados em zona rural e urbana

# %%
#Filtro Zona rural e urbana
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, situacao_domicilio \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND  unidade_federativa IN ({list_top_5}) \
          GROUP BY  unidade_federativa, situacao_domicilio"
resultado_domicilio = spark.sql(query)

domicilio_df = resultado_domicilio.toPandas()
domicilio_df = domicilio_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='situacao_domicilio', data=domicilio_df, palette='pastel')

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa e Situação de Domicílio')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
axis.yaxis.set_major_locator(ticker.MultipleLocator(250))
plt.ylim(0,2200)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Situação de Domicílio')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 13) Quantidade de casos separados por sexo

# %%
#Filtro Sexo
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, sexo \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, sexo"
resultado_sexo = spark.sql(query)

sexo_df = resultado_sexo.toPandas()
sexo_df = sexo_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='sexo', data=sexo_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa distribuídos por sexo')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_minor_locator(ticker.MultipleLocator(10))
axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
plt.ylim(700,1300)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Sexo')
plt.tight_layout()

plt.show()

# %% [markdown]
# ##14) Quantidade de casos separados se houve ou não sintomas

# %%
#Filtro Sintomas
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, teve_sintomas \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, teve_sintomas"
resultado_sintomas = spark.sql(query)

sintomas_df = resultado_sintomas.toPandas()
sintomas_df = sintomas_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='teve_sintomas', data=sintomas_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa distribuídos por sintomas')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Sintomas')
plt.tight_layout()

plt.show()

# %% [markdown]
# ##15) Quantidade de pessoas que procuraram um estabelecimento de saúde

# %%
#Filtro se buscou estabelecimento de saúde
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, visitou_estabelecimento_saude \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, visitou_estabelecimento_saude"
resultado_saude = spark.sql(query)

saude_df = resultado_saude.toPandas()
saude_df = saude_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='visitou_estabelecimento_saude', data=saude_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se buscou estabelecimento de saúde ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Buscou Estabelecimento de Saúde')
plt.tight_layout()

plt.show()

# %% [markdown]
# ##16) Quantidade de pessoas que buscaram atendimento médico

# %%
#Filtro se buscou atendimento médico
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, buscou_atendimento_medico \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, buscou_atendimento_medico"
resultado_atendimento = spark.sql(query)

atendimento_df = resultado_atendimento.toPandas()
atendimento_df = atendimento_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='buscou_atendimento_medico', data=atendimento_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se buscou atendimento médico ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Buscou atendimento médico')
plt.tight_layout()

plt.show()

# %% [markdown]
# ##17) Das pessoas que buscaram atendimento médico, quantas foram pelo SUS

# %%
#Filtro se buscou atendimento médico SUS
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, atendimento_sus \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) AND buscou_atendimento_medico = 'S' \
          GROUP BY  unidade_federativa, atendimento_sus"
resultado_sus = spark.sql(query)

sus_df = resultado_sus.toPandas()
sus_df = sus_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='atendimento_sus', data=sus_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se buscou atendimento no SUS ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_major_locator(ticker.MultipleLocator(50))
axis.yaxis.set_minor_locator(ticker.MultipleLocator(10))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Buscou atendimento médico no SUS')
plt.tight_layout()

plt.show()

# %% [markdown]
# ##18) Quantidade de pessoas que possuiam algum tipo de comorbidade

# %%
#Filtro se tinha comorbidade
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, possui_comorbidade \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, possui_comorbidade"
resultado_comorbidade = spark.sql(query)

comorbidade_df = resultado_comorbidade.toPandas()
comorbidade_df = comorbidade_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='possui_comorbidade', data=comorbidade_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se possuia comorbidade ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

#axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
#axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Possuia algum tipo de comorbidade')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 19) Quantidade de pessoas que estabeleceram algum tipo de restrição de contato

# %%
#Filtro restrição de contato
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, restricao_contato \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, restricao_contato"
resultado_contato = spark.sql(query)

contato_df = resultado_contato.toPandas()
contato_df = contato_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='restricao_contato', data=contato_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se restringiu contato com outras pessoas')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Restringiu contato com outras pessoas')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 20) Quantidade de pessoas de acordo com a ocupação

# %%
#Filtro natureza ocupação
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, ocupacao \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, ocupacao"
resultado_ocupacao = spark.sql(query)

ocupacao_df = resultado_ocupacao.toPandas()
ocupacao_df = ocupacao_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='ocupacao', data=ocupacao_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa de acordo com a Natureza da Ocupação')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Natureza Ocupação')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 21) Quantidade de pessoas de acordo com a faixa de rendimento

# %%
#Filtro faixa rendimento
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, faixa_rendimento \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, faixa_rendimento"
resultado_rendimento = spark.sql(query)

rendimento_df = resultado_rendimento.toPandas()
rendimento_df = rendimento_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='faixa_rendimento', data=rendimento_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa de acordo com a Faixa de Rendimento')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Faixa Rendimento')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 22) Quantidade de pessoas que estavam trabalhando em home office

# %%
#Filtro home office
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, home_office \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, home_office"
resultado_home_office = spark.sql(query)

home_office_df = resultado_home_office.toPandas()
home_office_df = home_office_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='home_office', data=home_office_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se fazia home office ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

#axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
#axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Fazia home office')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 23) Quantidade de pessoas que receberam auxilio emergencial

# %%
#Filtro auxilio emergencial
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, recebeu_auxilio_emergencial \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, recebeu_auxilio_emergencial"
resultado_auxilio = spark.sql(query)

auxilio_df = resultado_auxilio.toPandas()
auxilio_df = auxilio_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='recebeu_auxilio_emergencial', data=auxilio_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se recebeu auxílio emergencial ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

#axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
#axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Recebeu auxílio emergencial')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 24) Quantidade de pessoas que receberam seguro desemprego

# %%
#Filtro seguro desemprego
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, recebeu_seguro_desemprego \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, recebeu_seguro_desemprego"
resultado_seguro = spark.sql(query)

seguro_df = resultado_seguro.toPandas()
seguro_df = seguro_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='recebeu_seguro_desemprego', data=seguro_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se recebeu seguro desemprego ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

#axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
#axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Recebeu seguro desemprego')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 25) Quantidade de pessoas que solicitaram empréstimo

# %%
#Filtro empréstimo
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, solicitou_emprestimo \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, solicitou_emprestimo"
resultado_emprestimo = spark.sql(query)

emprestimo_df = resultado_emprestimo.toPandas()
emprestimo_df = emprestimo_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='solicitou_emprestimo', data=emprestimo_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se solicitou empréstimo ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

#axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
#axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Solicitou empréstimo')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 25) Quantidade de pessoas que possuiam acesso a itens básicos de limpeza e proteção

# %%
#Filtro acesso limpeza e protecao
query = f"SELECT unidade_federativa, count(resultado_teste) as qtd_positivos, possui_acesso_itens_basicos_limpeza_protecao \
          FROM tabela_temporaria \
          WHERE resultado_teste = 'positivo' AND unidade_federativa IN({list_top_5}) \
          GROUP BY  unidade_federativa, possui_acesso_itens_basicos_limpeza_protecao"
resultado_limpeza = spark.sql(query)

limpeza_df = resultado_limpeza.toPandas()
limpeza_df = limpeza_df.sort_values(by="unidade_federativa")

plt.figure(figsize=(12, 6))  # Tamanho do gráfico
axis=sns.barplot(x='unidade_federativa', y='qtd_positivos', hue='possui_acesso_itens_basicos_limpeza_protecao', data=limpeza_df, palette="pastel")

# Títulos e rótulos
plt.title('Quantidade de Positivos por Unidade Federativa se solicitou empréstimo ou não')
axis.set_xlabel('Unidade Federativa')
axis.set_ylabel('Quantidade de Positivos')

#axis.yaxis.set_major_locator(ticker.MultipleLocator(100))
#axis.yaxis.set_minor_locator(ticker.MultipleLocator(50))
#plt.ylim(0,2100)
plt.grid(linestyle='--')

plt.xticks(rotation=45)  # Rotacionar os nomes das unidades federativas para melhor visualização
plt.legend(title='Possuia acesso a itens básicos de limpeza e proteção')
plt.tight_layout()

plt.show()

# %% [markdown]
# ##26) Resultado Análise
# A partir dos dados analisados foram identificadas as seguintes características clínicas da população:
#   - As Unidades Federativas que tiveram mais pessoas que testaram positivo para COVID, sendo pelas técnicas de coleta por SWAB, sangue através de furo no dedo ou sangue através de veia do braço, foram:
#     - São Paulo com cerca de 2250 casos
#     - Rio de Janeiro com cerca de 2180 casos
#     - Maranhão com cerca de 2180 casos
#     - Goiás com cerca de 2050 casos
#     - Santa Catarina com cerca de 1650 casos
#   - A partir dessas 5 unidades federativas, considerando a população que testou positivo para COVID foram comparadas as quantidades de pessoas que viviam em zona rural e urbana. Nas 5 unidades federativas  a maioria dos casos ocorreram na zona urbana.
#   - Considerando a mesma população foram analisadas as quantidades de casos entre mulheres e homens. A maioria da população que testou positivo era de mulheres em todas as 5 unidades federativas.
#   - Dentro dos mesmos casos de pessoas que testaram positivo foram analisados quantos que tiveram sintomas (febre, tosse, dor de garganta, dificuldade para respirar, dor de cabeça, dor no peito, náusea, nariz entupido ou escorrendo, fadiga, dor nos olhos, perda de olfato ou paladar, dor muscular e diarréia). A grande maioria não considerou que tinha nenhum destes sintomas.
#   - Com a mesma população foram analisados quantos buscaram algum estabelecimento de saúde e/ou atendimento médico. A grande maioria que testou positivo não buscou nenhum das opções.
#   - Considerando a população com casos em que testaram positivo para COVID e que buscaram algum tipo de atendimento médico, foi analisada a relação de casos em que o atendimento foi feito pelo SUS e os feitos de forma privada. Em todos os 5 Estados a maioria dos atendimentos ocorreram no SUS. Sendo que no Rio de Janeiro mesmo sendo a maioria pelo SUS, a quantidade de atendimentos privados foi quase semelhante.
#   - Dentre a população analisada que testou positivo, foi identificado que a maioria não possuía nenhum tipo de comorbidade (diabetes, hipertensão, asma/bronquite/efisema/doenças respiratórias crônicas ou doença de pulmão, doenças do coração ou câncer).
#
# Sobre comportamento da população em relação a restrição de contato os comportamentos foram semelhantes entre as unidades federativas analisadas:
#   - A maioria das pessoas reduziu o contato com as pessoas, mas continuou saindo de casa para o trabalho ou atividades não essenciais e/ou recebendo visitas
#   - Seguido das pessoas que ficaram em casa e só saiu em caso de necessidade básica
#   - A minoria dos casos alegou ter ficado rigorosamente em casa, seguida da quantidade de pessoas que não aplicaram nenhum tipo de restrição
#
# Nas 5 unidades federativas a maioria das pessoas que testaram positivo eram empregadas do setor privado, sendo a maioria com concentração de renda entre R$ 800 a R$ 3.000.
#
# Das pessoas que testaram positivo a maioria fazia trabalho em home office.
#
# Sobre o recebimento do auxílio emergencial entre a população que testou positivo, somente no Maranhão a quantidade de pessoas que receberam o auxílio foi maior que os que não receberam.
#
# Nas 5 unidades federativas analisadas a grande maioria não recebeu seguro desemprego, nem solicitou empréstimo.
#
# Quanto ao acesso a itens básico de limpeza e higiene, em todos os 5 Estados analisados a grande maioria possuía acesso.
#
# Com base nos dados analisados e gráficos gerados, consideraria realizar as seguintes principais ações em um hospital num caso de um novo surto de COVID:
#   - Independente da pessoa manifestar sintomas ou possuir comorbidades, se faz necessário realizar testes de covid em toda a população.
#   - Como a maioria dos casos procurou atendimento no SUS, priorizaria a compra de testes com custo menor para garantir que todos que procurem atendimento consigam ser testados.
#   - Ao identificar que algum paciente testou positivo, se faz necessário orientar os pacientes a evitarem contato o máximo possível, para evitar que novas pessoas se infectem.
# Também focaria o atendimento do hospital para casos de população carente que recebe até 2 salários mínimos. Ofertando valores de tratamento mais acessíveis e com condições diferenciadas de pagamento.
